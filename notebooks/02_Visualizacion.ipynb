# %% [markdown]
# <div align="center">
#
# # ⚽ Visualizaciones de la Premier League
#
# </div>

# %% [markdown]
# ### 📉 **Interpretación del Gráfico Goles.**

# %% [markdown]
# ![grafico](Grafico1.png)

# %% [markdown]
# En este gráfico podemos observar cuantos partidos se gudaron y la cantidad de goles que se realizarón.
#
# En el eje x tenemos los goles de los partidos.
# En el eje y la frecuencia osea la cantidad de partidos que tuvieron el numero de goles.
#
# Podemos interpretra que la mayoria de los partidos tienen pocos goles, podemos observar que lo más alto esta en 0 goles lo que nos podria estar indicando que la mayoria de partidos terminan en empates 0-0. Pero tambien podemos observar que hay una pequeña frecuencia que esta aumentando y nos indica que entre los partidos podrian llegar a terminar en 1-0.
#
# A partir de 2 goles, la frecuencia es baja, esto nos indica que los partidos con 3 o más goles son raros.
#
# Con respecto a la curva que se observa en el grafico nos puede indicar que la probabilidad de anotar muchos goles es muy bajo.
#
#
# En conclusión podemos decir que el la Premier League tiene equipos muy defensivos, por la tanto en el grafico se muestra que la mayoria de partidos terminan en 0-0.

# %% [markdown]
# ### 📊 **Interpretación del Gráfico Goles.**

# %% [markdown]
# ![grafico](Grafico2.png)

# %% [markdown]
# En este diagrama de dispersión nos representa la realcion entre:
#
# El eje x que son los tiros totales por equipos.
# El eje y son los goles anotados.
#
# Podemos interpretar que a medida que aumentan los tiros totales, también tienden a aumentar los goles, esto nos da una correlación positiva, ya que entre mas intentos de tiros más posibilidades de goles de anotar. Tambien podemos indicar que este gráfico tiene una dispersión muy amplia, ya que, tambien podemos decir que hay partidos con muchos tiros y pocos goles, lo que indica baja efectividad, pero por otro lado hay puntos con pocos tiros y varios goles, lo que sugiere alta eficiencia.
#
# En conclusión podemos decir que hay equipos con muchos tiros pero pocos goles que podrían necesitar mejorar su precisión o calidad de tir y los equipos con pocos tiros y muchos goles podrían estar aprovechando mejor sus oportunidades.

# %% [markdown]
# ### 📈 **Interpretación del Gráfico Goles.**

# %% [markdown]
# ![grafico](Grafico3.png)

# %% [markdown]
# En este diagrama tenemos el Top 10 goleadores de la Premier League (2024-2025).
#
# En el eje x tenemos los nombres de los jugadores.
# En el eje y tenemos los goles que han realizado en ese tiempo.
#
# Podemos interpretar que el Top 1 es Mohamed Salah con más de 12 goles, lo que refleja su consistencia y experiencia en la liga. Como un jugador veterano, se podria decir que tiene técnica profundas en cada juego, lo que le permite aprovechar sus oportunidades con gran energia. Le sigue Erling Haaland con 11 goles, se podria decir que es uno de los referentes de la “nueva generación” de futbolistas, el impacto que ha generado desde su llegada a la Premier League, se ha podido destacar por su potencia física, precisión y popularidad.
#
# En conclusión, este gráfico no solo nos muestra ese Top goleadores sino que también permite observar la diversidad de estilos entre jugadores como Salah y Haaland. Este gráfico nos es muy útil para analizar tendencias ofensivas y el perfil de los jugadores más determinantes en la temporada.

# %% [markdown]
# ### 📊 **Interpretación del Gráfico Goles.**

# %% [markdown]
# ![grafico](Grafico4.png)

# %% [markdown]
# Este gráfico nos muestra el Top 10 de jugadores con más asistencias en la Premier League.
#
# En el eje x son los nombres de los jugadores.
# En el eje y son el número de asistencia.
#
# Podemos observar que Bukayo Saka lidera el ranking con 10 asistencias, lo que destaca su evolución como un jugador clave en la posición defensiva, luego le sigue Salah con 8 asistencias, lo que complementa su rol como goleador, como podemos ver él no solo se destaca por marcar goles si no que tambien por dar asistencias para que sus compañeros puedan marcar. El resto de jugadores como Bruno Fernandes, se sitúan entre 5 y 6 asistencias, mostrando una contribución constante pero menos dominante.
#
# En conclusión, este gráfico revela que los Top en asistencias no solo se destacan por su técnica, sino también por su capacidad de lectura del juego y conexión con el equipo. La presencia de Saka y Salah en los primeros puestos refleja un equilibrio entre juventud y experiencia en la creación ofensiva.
